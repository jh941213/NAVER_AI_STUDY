# %% [markdown]
# <a href="https://colab.research.google.com/github/jh941213/NAVER_AI_STUDY/blob/main/boost_course_1weeks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Q1. 파이썬에서는 리스트 형태의 데이터를 자주 사용합니다. 그래서 리스트 를 잘 다루는 것이 중요한데, 다음으로 주어진 리스트 데이터를 다뤄봅시다.😎
#
# - 다양한 데이터를 수집해서 아래와 같은 num_list를 얻었습니다.
#
# - 하지만 우리에게 필요한 데이터는 홀수 데이터입니다.
#
# - 그렇다면 num_list 가 홀수인 데이터만 출력하도록 하는 함수를 작성해보세요.
# ![스크린샷 2023-01-16 오후 11.52.07.png](data:image/png;base64,...)

# %%
#내 풀이
# 주어진 리스트
num_list = [1, 5, 7, 15, 16, 22, 28, 29]
bin_list = []
def get_odd_num(num_lsit):
    
    for i in num_list:
        if i%2==1:
            bin_list.append(i)
    return bin_list
    # TODO

print(get_odd_num(num_list))
# Out:
# [1, 5, 7, 15, 29]

# %%
# 팀원 솔루션
num_list = [1, 5, 7, 15, 16, 22, 28, 29]
def get_odd_num(num_list):
    return [i for i in num_list if i%2==1]
print(get_odd_num(num_list))
# Out:
# [1, 5, 7, 15, 29]

# %% [markdown]
# ## Q2. 데이터 처리를 위해서 문자열을 입력받았습니다. 그런데, 문자열을 받았 더니 단어 단위로 거꾸로 입력되었습니다. 이를 다시 원래대로 출력하는 함수 를 작성해보세요.😎
#
# - string 문장을 받아 단어를 역순으로 출력하는 함수를 작성하세요.
# - string 연산을 이용해보세요.
# ![스크린샷 2023-01-17 오전 12.00.29.png](data:image/png;base64,...)

# %%
sentence = "way a is there will a is there Where"
bin_list = []
def reverse_sentence(sentence):
# TODO
    sentence=sentence.split(' ')
    reverse = sentence[::-1]
    total = ' '.join(reverse)
    return total


print(reverse_sentence(sentence))
# Out:
# Where there is a will there is a way

# %%
sentence = "way a is there will a is there Where"
bin_list = []
def reverse_sentence(sentence):
# TODO
    sentence=sentence.split(' ')
    total = sentence.reverse()
    return total

print(reverse_sentence(sentence))
# Out:
# None

# %%
sentence = "way a is there will a is there Where"
sentence=sentence.split(' ')
total = sentence.reverse()

print(total)
# Out:
# None

# %% [markdown]
# ## Q3. 이번 학기의 중간고사, 기말고사 점수가 발표되었습니다. 각 학생들의 점 수가 튜플 형태로 저장되어 있고, 이를 포함한 리스트가 있습니다. 이를 이용 해 각 학생들의 평균 점수를 출력하는 함수를 제작하세요. 😎
# - 리스트와 반복문을 사용해 데이터를 불러오세요.
# - 이를 이용해 각 학생별 평균을 구해보세요![스크린샷 2023-01-17 오전 12.19.23.png](data:image/png;base64,...)

# %%
# 주어진 점수
scores = [(100, 100), (95, 90), (55, 60), (75, 80), (70, 70)]

def get_avg(scores):
    for idx, i in enumerate(scores):
        
        print(f'{idx+1} 번, 평균 : {sum(i)/len(i)}')
get_avg(scores)
# Out:
# 1 번, 평균 : 100.0
# 2 번, 평균 : 92.5
# 3 번, 평균 : 57.5
# 4 번, 평균 : 77.5
# 5 번, 평균 : 70.0

# %% [markdown]
# ## Q4. 두개의 납품처에서 각각 과일과 야채들이 납품되었습니다. 이를 각각 물 품의 갯수를 나타내는 2개의 딕셔너리로 정리했습니다. 물품을 정리하기 위해서 2 개의 딕셔너리 객체를 합쳐 출력하는 함수를 제작하세요.😎
#
# - 중복되는 물품은 합쳐서 표시하세요.
# - 각 딕셔너리 데이터의 데이터의 키값을 이용해 중복을 확인해보세요.

# %%
dict_first = {'사과': 30, '배': 15, "감": 10, "포도":10}
dict_second = {'사과': 5, '감': 25, "배": 15, "귤":25}

def merge_dict(dict_first, dict_second):
    # 집합 자료형으로 중복 과일 이름 제거 ( )
    fruit_list = set(dict_first.keys()) | set(dict_second.keys())
    # 값을 0으로 갖는 딕셔너리 생성
    dict_result = {fruit:0 for fruit in fruit_list}
    for fruit,price in dict_result.items():
        # 첫 번째 딕셔너리에 과일이 존재하면 값을 더함
        if fruit in dict_first:
            dict_result[fruit] += dict_first[fruit]
        # 두 번째 딕셔너리에 과일이 존재하면 값을 더함
        if fruit in dict_second:
            dict_result[fruit] += dict_second[fruit]

    # 문제에서 요구하는 형태로 맞춰주기 위해 key 정렬 및 dictionary 자료형으로 반환
    return dict(sorted(dict_result.items()))


merge_dict(dict_first, dict_second)

# %%
fruit_list = ['사과', '배', '감', '귤']
for fruit in fruit_list:
    dict_lesult = {fruit:0}
    print(dict_lesult)
# Out:
# {'사과': 0}
# {'배': 0}
# {'감': 0}
# {'귤': 0}

# %%
# Out:
# {'귤': 0}

# %% [markdown]
# ## Q5. 단어들을 입력받았는데, 자꾸만 숫자들이 섞여들어가는 문제가 있습니 다. 이를 처리하기 위해서 함수에 string을 전달 받은 뒤, string 안에서의 숫 자를 제거한 후 string만 남은 리스트를 출력하세요. 😎
#
# - string 연산을 이용해서 문자열을 자르는 연산을 사용해보세요.

# %%
# 주어진 입력 string
inputs = "cat32dog16cow5"

def find_string(inputs):
    # 숫자가 아니면 list로 변환
    input_list = [word for word in inputs if not word.isdigit()]
    # 3 칸씩 인덱스를 띄워가며 string 병합하고 list로 변환하여 반환
    input_list = [input_list[idx] + input_list[idx+1] + input_list[idx+2] for idx in range(0,len(input_list),3)]
    # 또 다른 선택지
    # 정규표현식 사용
    # ASCII 코드값 사용
    return input_list

string_list = find_string(inputs)
print(string_list)
